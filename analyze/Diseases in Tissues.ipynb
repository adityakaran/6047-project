# %%
from disease import Disease
from tissue import Tissue
import interactome as I
ixome = I.Interactome(I.PATH + I.INTERACTOME_FILE)

# %%
hippocampus = Tissue("hippocampus_entrez", ixome)

# %%
schizo = Disease("schizophrenia", ixome)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 12))
schizo.show_disease_graph(hippocampus)

# %%
liver = Tissue("liver_entrez", ixome)

# %%
plt.figure(figsize=(12, 12))
schizo.show_disease_graph(liver)

# %%
frontal_cortex = Tissue("frontal_cortex_entrez", ixome)

# %%
schizo.show_disease_graph(frontal_cortex)

# %%
liver_frontal = Tissue("liver_frontal_cortex_entrez", ixome)

# %%
schizo.show_disease_graph(liver_frontal)

# %%
diabetes = Disease("diabetes", ixome)
diabetes.show_disease_graph(frontal_cortex)

# %%
heart = Tissue("heart_entrez", ixome)

# %%
diabetes.show_disease_graph(heart)

# %%
schizo.show_disease_graph(heart)

# %%
diabetes.show_disease_graph(liver)

# %%
diabetes.show_disease_graph(hippocampus)

# %%
bipolar = Disease("bipolar-gwas", ixome)

# %%
bipolar.show_disease_graph(frontal_cortex)

# %%
bipolar.show_disease_graph(liver)

# %%
bipolar.show_disease_graph(hippocampus)

# %%
bipolar.show_disease_graph(heart)

# %%
autism = Disease("autism-all", ixome)

# %%
heart_disease = Disease("heart_disease", ixome)

# %%
autism.show_disease_graph(hippocampus)

# %%
autism.show_disease_graph(liver)

# %%
autism.show_disease_graph(heart)

# %%
autism.show_disease_graph(frontal_cortex)

# %%
heart_disease.show_disease_graph(hippocampus)

# %%
heart_disease.show_disease_graph(frontal_cortex)

# %%
heart_disease.show_disease_graph(liver)

# %%
heart_disease.show_disease_graph(heart)

# %%
import networkx as nx
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 12))
nx.draw_networkx(schizo.subgraph, with_labels=False, node_size=12)

# %%
plt.figure(figsize=(12, 12))
nx.draw_networkx(bipolar.subgraph, with_labels=False, node_size=12)

# %%
plt.figure(figsize=(12, 12))
nx.draw_networkx(autism.subgraph, with_labels=False, node_size=12)

# %%
plt.figure(figsize=(12, 12))
nx.draw_networkx(diabetes.subgraph, with_labels=False, node_size=12)

# %%
plt.figure(figsize=(12, 12))
nx.draw_networkx(heart_disease.subgraph, with_labels=False, node_size=12)
